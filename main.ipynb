# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd drive/MyDrive/Purdue-stuff/ECE570/Project/Unofficial-implementations/Deep-Clustering-Network-master/DCN-xuyxu-convnet-unet/
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Purdue-stuff/ECE570/Project/Unofficial-implementations/Deep-Clustering-Network-master/DCN-xuyxu-convnet-unet

# %%
# !python mnist.py --pre-epoch 50 --epoch 50
# Out:
# ========== Start pretraining ==========
# Epoch: 00 | Batch: 000 | Rec-Loss: 3.375
# Epoch: 00 | Batch: 100 | Rec-Loss: 3.153
# Epoch: 00 | Batch: 200 | Rec-Loss: 2.970
# Epoch: 01 | Batch: 000 | Rec-Loss: 2.892
# Epoch: 01 | Batch: 100 | Rec-Loss: 2.717
# Epoch: 01 | Batch: 200 | Rec-Loss: 2.553
# Epoch: 02 | Batch: 000 | Rec-Loss: 2.486
# Epoch: 02 | Batch: 100 | Rec-Loss: 2.357
# Epoch: 02 | Batch: 200 | Rec-Loss: 2.257
# Epoch: 03 | Batch: 000 | Rec-Loss: 2.211
# Epoch: 03 | Batch: 100 | Rec-Loss: 2.161
# Epoch: 03 | Batch: 200 | Rec-Loss: 2.085
# Epoch: 04 | Batch: 000 | Rec-Loss: 2.056
# Epoch: 04 | Batch: 100 | Rec-Loss: 2.006
# Epoch: 04 | Batch: 200 | Rec-Loss: 1.972
# Epoch: 05 | Batch: 000 | Rec-Loss: 1.940
# Epoch: 05 | Batch: 100 | Rec-Loss: 1.902
# Epoch: 05 | Batch: 200 | Rec-Loss: 1.872
# Epoch: 06 | Batch: 000 | Rec-Loss: 1.835
# Epoch: 06 | Batch: 100 | Rec-Loss: 1.817
# Epoch: 06 | Batch: 200 | Rec-Loss: 1.795
# Epoch: 07 | Batch: 000 | Rec-Loss: 1.771
# ...
